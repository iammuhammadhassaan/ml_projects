# %% [markdown]
# # **Rice Diseases are classified using CNN with Tensorflow**
#
# <h1 style="font-family: 'poppins'; font-weight: bold; color: Blue;">👨‍💻Author: Muhammad Hassaan</h1>
#
# [![GitHub](https://img.shields.io/badge/GitHub-Profile-blue?style=for-the-badge&logo=github)](https://github.com/MHassaan2)
# [![Kaggle](https://img.shields.io/badge/Kaggle-Profile-blue?style=for-the-badge&logo=kaggle)](https://www.kaggle.com/mhassaan1122)
# [![LinkedIn](https://img.shields.io/badge/LinkedIn-Profile-blue?style=for-the-badge&logo=linkedin)](https://www.linkedin.com/in/iammuhammadhassaan7/)
# [![Email](https://img.shields.io/badge/Email-Contact%20Me-red?style=for-the-badge&logo=email)](mailto:muhammadhassaan7896@gmail.com)

# %% [markdown]
# ### Rice Disease Project
# Developed a Convolutional Neural Network (CNN) model to detect and classify rice diseases from images with [specific percentage] accuracy. Deployed the model using Streamlit for real-time detection through user-uploaded images.

# %%
# import libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import tensorflow as tf

# %%
# import train.csv file
data = pd.read_csv("../data/train.csv")
data.head()
# Out:
#      image_id                  label variety  age
# 0  100330.jpg  bacterial_leaf_blight   ADT45   45
# 1  100365.jpg  bacterial_leaf_blight   ADT45   45
# 2  100382.jpg  bacterial_leaf_blight   ADT45   45
# 3  100632.jpg  bacterial_leaf_blight   ADT45   45
# 4  101918.jpg  bacterial_leaf_blight   ADT45   45

# %%
# check the shape of data
data.shape
# Out:
# (10407, 4)

# %%
data['label'].unique().tolist()
# Out:
# ['bacterial_leaf_blight',
#  'bacterial_leaf_streak',
#  'bacterial_panicle_blight',
#  'blast',
#  'brown_spot',
#  'dead_heart',
#  'downy_mildew',
#  'hispa',
#  'normal',
#  'tungro']

# %%
data['variety'].unique().tolist()
# Out:
# ['ADT45',
#  'IR20',
#  'KarnatakaPonni',
#  'Onthanel',
#  'Ponni',
#  'Surya',
#  'Zonal',
#  'AndraPonni',
#  'AtchayaPonni',
#  'RR']

# %%
data['age'].describe()
# Out:
# count    10407.000000
# mean        64.043624
# std          8.958830
# min         45.000000
# 25%         60.000000
# 50%         67.000000
# 75%         70.000000
# max         82.000000
# Name: age, dtype: float64

# %%
# plot the data count based on variety name
fig,axes = plt.subplots(1,1,figsize=(21,7))
sns.histplot(data,x='variety',ax=axes)
plt.title('Variety distribution in the dataset')
plt.show()

# %%
# plot the data count based on variety name
fig,axes = plt.subplots(1,1,figsize=(21,7))
sns.histplot(data,x='label',ax=axes)
plt.title('Disease distribution in the dataset')
plt.show()

# %%
normal = data[data['label'] =='normal']
normal = normal[normal['variety'] =='ADT45']
five_normals = normal.image_id[:5].values
five_normals.tolist()
# Out:
# ['100007.jpg', '100025.jpg', '100135.jpg', '100165.jpg', '100171.jpg']

# %%
dead = data[data['label'] =='dead_heart']
dead = dead[dead['variety'] =='ADT45']
five_deads= dead.image_id[:5].values
five_deads.tolist()
# Out:
# ['101165.jpg', '102750.jpg', '108367.jpg', '109900.jpg', '100222.jpg']

# %%
# make plot of images just to have an idea
plt.figure(figsize=(20,10))
columns = 5
path = '../data/train_images/'
for i, image_loc in enumerate(np.concatenate((five_normals, five_deads))):
    plt.subplot(10//columns + 1, columns, i + 1)
    
    if i < 5:
        image=plt.imread(path +"normal/"+ image_loc)
        plt.title("normal")
    else:
        plt.title("dead heart disease")
        image=plt.imread(path +"dead_heart/"+ image_loc)
        
    plt.imshow(image)

# %%
images = ['../data/train_images/hispa/106590.jpg',\
          '../data/train_images/tungro/109629.jpg',\
          '../data/train_images/bacterial_leaf_blight/109372.jpg',\
          '../data/train_images/downy_mildew/102350.jpg',\
          '../data/train_images/blast/110243.jpg',\
          '../data/train_images/bacterial_leaf_streak/101104.jpg',\
          '../data/train_images/normal/109760.jpg',\
          '../data/train_images/brown_spot/104675.jpg',\
          '../data/train_images/dead_heart/105159.jpg',\
          '../data/train_images/bacterial_panicle_blight/101351.jpg',\
         ]
diseases = ['hispa','tungro','bacterial_leaf_blight','downy_mildew','blast','bacterial_leaf_streak',\
           'normal','brown_spot','dead_heart','bacterial_panicle_blight']
diseases = [disease + ' image' for disease in diseases]
plt.figure(figsize=(20,10))
columns = 5
for i, image_loc in enumerate(images):
    plt.subplot(len(images)//columns + 1, columns, i + 1)
    image=plt.imread(image_loc)
    plt.title(diseases[i])
    plt.imshow(image)

# %%
data.head()
# Out:
#      image_id                  label variety  age
# 0  100330.jpg  bacterial_leaf_blight   ADT45   45
# 1  100365.jpg  bacterial_leaf_blight   ADT45   45
# 2  100382.jpg  bacterial_leaf_blight   ADT45   45
# 3  100632.jpg  bacterial_leaf_blight   ADT45   45
# 4  101918.jpg  bacterial_leaf_blight   ADT45   45

# %%
# encode both columns label and variety
from sklearn.preprocessing import LabelEncoder

label_encoder = LabelEncoder()
data['label'] = label_encoder.fit_transform(data['label'])
data['variety'] = label_encoder.fit_transform(data['variety'])

data.head()
# Out:
#      image_id  label  variety  age
# 0  100330.jpg      0        0   45
# 1  100365.jpg      0        0   45
# 2  100382.jpg      0        0   45
# 3  100632.jpg      0        0   45
# 4  101918.jpg      0        0   45

# %%
# define parameter
batch_size = 32
img_height = 224
img_width = 224

# %%
train_ds = tf.keras.utils.image_dataset_from_directory(
  path,
  validation_split=0.2,
  subset="training",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 10407 files belonging to 10 classes.
# Using 8326 files for training.

# %%
val_ds = tf.keras.utils.image_dataset_from_directory(
  path,
  validation_split=0.2,
  subset="validation",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 10407 files belonging to 10 classes.
# Using 2081 files for validation.

# %%
class_names = train_ds.class_names
print(class_names)
# Out:
# ['bacterial_leaf_blight', 'bacterial_leaf_streak', 'bacterial_panicle_blight', 'blast', 'brown_spot', 'dead_heart', 'downy_mildew', 'hispa', 'normal', 'tungro']

# %%
for image_batch, labels_batch in train_ds:
  print(image_batch.shape)
  print(labels_batch.shape)
  break
# Out:
# (32, 224, 224, 3)
# (32,)

# %%
normalization_layer = tf.keras.layers.Rescaling(1./255)

# %%
normalized_ds = train_ds.map(lambda x, y: (normalization_layer(x), y))
image_batch, labels_batch = next(iter(normalized_ds))
first_image = image_batch[0]
# Notice the pixel values are now in `[0,1]`.
print(np.min(first_image), np.max(first_image))
# Out:
# 0.0 1.0

# %%
AUTOTUNE = tf.data.AUTOTUNE

train_ds = train_ds.cache().prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %%
num_classes = len(class_names)
num_classes
# Out:
# 10

# %%
model = tf.keras.Sequential([
  tf.keras.layers.Rescaling(1./255),
  tf.keras.layers.Conv2D(128, 3, activation='relu'),
  tf.keras.layers.MaxPooling2D(),
  tf.keras.layers.Conv2D(64, 3, activation='relu'),
  tf.keras.layers.MaxPooling2D(),
  tf.keras.layers.Conv2D(32, 3, activation='relu'),
  tf.keras.layers.MaxPooling2D(),
  tf.keras.layers.Conv2D(16, 3, activation='relu'),
  tf.keras.layers.MaxPooling2D(),
  tf.keras.layers.Flatten(),
  tf.keras.layers.Dropout(0.25),
  tf.keras.layers.Dense(128, activation='relu'),
  tf.keras.layers.Dense(num_classes, activation='softmax')
])

# %%
model.compile(
  optimizer='adam',
  loss=tf.losses.SparseCategoricalCrossentropy(from_logits=True),
  metrics=['accuracy'])

# %%
# %%time
#remove warnings
import warnings
warnings.filterwarnings('ignore')

from tensorflow.keras.callbacks import EarlyStopping
# Define the callback function
early_stopping = EarlyStopping(patience=3)

history= model.fit(train_ds,
          validation_data=val_ds,
          epochs=100,
          callbacks=[early_stopping])

# evaluat the model
loss = model.evaluate(val_ds)

# Plotting the training and testing loss
import matplotlib.pyplot as plt
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='upper right')
plt.show()

# plot the accuracy of training and validation

# Plotting the training and validation accuracy
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Validation'], loc='lower right')
plt.show()
# Out:
# Epoch 1/100
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 708s 3s/step - accuracy: 0.2045 - loss: 2.1297 - val_accuracy: 0.3984 - val_loss: 1.7561
# Epoch 2/100
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 722s 3s/step - accuracy: 0.4529 - loss: 1.5990 - val_accuracy: 0.5536 - val_loss: 1.3453
# Epoch 3/100
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 711s 3s/step - accuracy: 0.6382 - loss: 1.0731 - val_accuracy: 0.6660 - val_loss: 1.0922
# Epoch 4/100
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 664s 3s/step - accuracy: 0.7616 - loss: 0.7490 - val_accuracy: 0.7126 - val_loss: 0.9812
# Epoch 5/100
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 775s 3s/step - accuracy: 0.8096 - loss: 0.5589 - val_accuracy: 0.7472 - val_loss: 0.8909
# Epoch 6/100
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 769s 3s/step - accuracy: 0.8507 - loss: 0.4662 - val_accuracy: 0.7737 - val_loss: 0.8909
# Epoch 7/100
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 779s 3s/step - accuracy: 0.9035 - loss: 0.2945 - val_accuracy: 0.7741 - val_loss: 0.8957
# Epoch 8/100
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 752s 3s/step - accuracy: 0.9117 - loss: 0.2705 - val_accuracy: 0.8006 - val_loss: 0.8282
# Epoch 9/100
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 769s 3s/step - accuracy: 0.9303 - loss: 0.2038 - val_accuracy: 0.8059 - val_loss: 0.8061
# Epoch 10/100
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 738s 3s/step - accuracy: 0.9465 - loss: 0.1600 - val_accuracy: 0.8107 - val_loss: 0.9052
# Epoch 11/100
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 876s 3s/step - accuracy: 0.9524 - loss: 0.1446 - val_accuracy: 0.8241 - val_loss: 0.9185
# Epoch 12/100
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 847s 3s/step - accuracy: 0.9569 - loss: 0.1311 - val_accuracy: 0.8102 - val_loss: 0.8732
# Epoch 13/100
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 731s 3s/step - accuracy: 0.9668 - loss: 0.1084 - val_accuracy: 0.8232 - val_loss: 0.9623
# Epoch 14/100
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 752s 3s/step - accuracy: 0.9703 - loss: 0.0958 - val_accuracy: 0.8294 - val_loss: 0.8290
# Epoch 15/100
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 777s 3s/step - accuracy: 0.9657 - loss: 0.1040 - val_accuracy: 0.8275 - val_loss: 0.9008
# Epoch 16/100
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 745s 3s/step - accuracy: 0.9717 - loss: 0.0923 - val_accuracy: 0.8241 - val_loss: 0.9443
# Epoch 17/100
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 754s 3s/step - accuracy: 0.9772 - loss: 0.0693 - val_accuracy: 0.8357 - val_loss: 0.8974
# Epoch 18/100
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 718s 3s/step - accuracy: 0.9720 - loss: 0.0908 - val_accuracy: 0.8241 - val_loss: 0.9793
# Epoch 19/100
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 687s 3s/step - accuracy: 0.9739 - loss: 0.0795 - val_accuracy: 0.8347 - val_loss: 0.9439
# Epoch 20/100
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 677s 3s/step - accuracy: 0.9809 - loss: 0.0607 - val_accuracy: 0.8169 - val_loss: 1.0161
# Epoch 21/100
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 677s 3s/step - accuracy: 0.9747 - loss: 0.0870 - val_accuracy: 0.8212 - val_loss: 1.1095
# Epoch 22/100
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 699s 3s/step - accuracy: 0.9750 - loss: 0.0875 - val_accuracy: 0.8390 - val_loss: 0.9204
# Epoch 23/100
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 685s 3s/step - accuracy: 0.9806 - loss: 0.0667 - val_accuracy: 0.8313 - val_loss: 0.9820
# Epoch 24/100
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 722s 3s/step - accuracy: 0.9812 - loss: 0.0610 - val_accuracy: 0.8433 - val_loss: 0.9979
# Epoch 25/100
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 732s 3s/step - accuracy: 0.9837 - loss: 0.0486 - val_accuracy: 0.8385 - val_loss: 0.9702
# Epoch 26/100
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 698s 3s/step - accuracy: 0.9828 - loss: 0.0545 - val_accuracy: 0.8299 - val_loss: 0.9678
# Epoch 27/100
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 762s 3s/step - accuracy: 0.9870 - loss: 0.0409 - val_accuracy: 0.8294 - val_loss: 1.0741
# Epoch 28/100
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 740s 3s/step - accuracy: 0.9790 - loss: 0.0701 - val_accuracy: 0.8309 - val_loss: 1.0016
# Epoch 29/100
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 757s 3s/step - accuracy: 0.9788 - loss: 0.0783 - val_accuracy: 0.8352 - val_loss: 1.0432
# Epoch 30/100
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 730s 3s/step - accuracy: 0.9792 - loss: 0.0661 - val_accuracy: 0.8424 - val_loss: 0.9566
# Epoch 31/100
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 708s 3s/step - accuracy: 0.9862 - loss: 0.0460 - val_accuracy: 0.8405 - val_loss: 1.0715
# Epoch 32/100
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 686s 3s/step - accuracy: 0.9867 - loss: 0.0403 - val_accuracy: 0.8457 - val_loss: 0.9196
# Epoch 33/100
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 687s 3s/step - accuracy: 0.9827 - loss: 0.0524 - val_accuracy: 0.8390 - val_loss: 1.0894
# Epoch 34/100
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 683s 3s/step - accuracy: 0.9860 - loss: 0.0518 - val_accuracy: 0.8443 - val_loss: 1.0964
# Epoch 35/100
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 688s 3s/step - accuracy: 0.9828 - loss: 0.0555 - val_accuracy: 0.8424 - val_loss: 0.9915
# Epoch 36/100
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 682s 3s/step - accuracy: 0.9834 - loss: 0.0463 - val_accuracy: 0.8491 - val_loss: 1.0680
# Epoch 37/100
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 691s 3s/step - accuracy: 0.9897 - loss: 0.0392 - val_accuracy: 0.8347 - val_loss: 1.1346
# Epoch 38/100
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 685s 3s/step - accuracy: 0.9861 - loss: 0.0416 - val_accuracy: 0.8294 - val_loss: 1.0053
# Epoch 39/100
# 261/261 ━━━━━━━━━━━━━━━━━━━━ 683s 3s/step - accuracy: 0.9845 - loss: 0.0523 - val_accuracy: 0.8347 - val_loss: 1.1381
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 30s 458ms/step - accuracy: 0.8238 - loss: 1.2953
# CPU times: total: 3d 50min 10s
# Wall time: 7h 52min 58s

# %%
# Save the model
model.save('../neuralnetwork.keras')

# %% [markdown]
# ## Observations:
# 1. We have 10407, images in train data.
# 2. We have 10 unique disease classes.
# 3. We also have 10 variesites of RICE in this data.
# 4. We have rice plant age ranging from 45 - 85 days.
# 5. ADT45 is the most common variety inside the training data.

# %%
import tensorflow as tf
print(tf.reduce_sum(tf.random.normal([1000, 1000])))
# Out:
# tf.Tensor(75.145874, shape=(), dtype=float32)

# %%
import tensorflow as tf
print(tf.config.list_physical_devices('GPU'))
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
